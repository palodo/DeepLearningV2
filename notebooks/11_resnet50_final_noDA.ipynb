# %% [markdown]
# # 🧠 Modelo 11: ResNet50 SIN Data Augmentation - Multi-Seed Analysis
#
# En este notebook entrenamos **ResNet50 sin Data Augmentation** usando **5 semillas diferentes** para evaluar la robustez y variabilidad del modelo. Cada entrenamiento corre 100 épocas completas, visualizamos cada curva por separado y calculamos la media ± desviación estándar de las métricas finales.
#
# **Diferencia clave respecto a Notebook 10:** No aplicamos transformaciones de aumento de datos (RandomFlip, Rotation, Zoom, etc). Esto permite comparar directamente el impacto de la data augmentation en la generalización.
#
# ---

# %% [markdown]
# ## 0. Configuración Inicial e Imports

# %%
import os
import sys

# ⚠️ IMPORTANTE: Estas líneas DEBEN ir ANTES de importar TensorFlow
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # Suprime todos los mensajes (INFO, WARNING, ERROR)
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'  # Desactiva mensajes de oneDNN
os.environ['CUDA_VISIBLE_DEVICES'] = '3'

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import kagglehub
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras import layers

# Suprimir warnings de TensorFlow adicionales
import warnings
warnings.filterwarnings('ignore')
tf.get_logger().setLevel('ERROR')

# Añadir el directorio raíz al path para importar módulos locales
sys.path.append('..')
import oct_dataloader as dataloaders
import modelos.modelo_resnet50_unfrozen as resnet_model

print("✅ Librerías e importaciones listas")
# Out:
# ✅ Librerías e importaciones listas

# %%
# Configurar GPUs
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"GPU detectada(s): {gpus}")
    except RuntimeError as e:
        print(e)
else:
    print("⚠️ No se detectó GPU. Se usará la CPU.")
# Out:
# GPU detectada(s): [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Función para establecer semillas (reproducibilidad)
def set_seeds(seed):
    """Configura todas las semillas aleatorias para reproducibilidad."""
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    tf.keras.utils.set_random_seed(seed)

# %% [markdown]
# ## 1. Carga de Datos (RGB para ResNet50)
#
# **IMPORTANTE**: ResNet50 está diseñado para imágenes en color (3 canales). Cargamos los datos UNA SOLA VEZ y entrenaremos SIN aplicar augmentation.

# %%
# Descargar/Localizar dataset
path = kagglehub.dataset_download("anirudhcv/labeled-optical-coherence-tomography-oct")
data_path = path
for root, dirs, files in os.walk(path):
    if 'train' in dirs and 'test' in dirs:
        data_path = root
        break

# Configuración del DataLoader
IMG_SIZE = (224, 224)
BATCH_SIZE = 256
SUBSET = 1

train_ds, val_ds, test_ds, class_names = dataloaders.create_oct_dataloaders(
    data_path=data_path,
    img_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    color_mode='rgb',  # <--- OBLIGATORIO para ResNet50
    train_subset_fraction=SUBSET,
    optimize=False
)

print(f"✅ Dataset cargado. Clases: {class_names}")
# Out:
# ⚙️ Configuración de DataLoaders
#    • Tamaño de imagen: (224, 224)
#    • Batch size: 256
#    • Label mode: int
#    • Clases: ['CNV', 'DME', 'DRUSEN', 'NORMAL']
#    • Train subset: 100.0%
#    • Seed: 42
#
# 📦 Creando data loader de entrenamiento...
# Found 76515 files belonging to 4 classes.
# ✅ Data loader de entrenamiento creado
#
# 📦 Creando data loader de validación...
# Found 21861 files belonging to 4 classes.
# ✅ Data loader de validación creado
#
# 📦 Creando data loader de prueba...
# Found 10933 files belonging to 4 classes.
# ✅ Data loader de prueba creado
#
# ============================================================
# 📊 RESUMEN DE DATASETS
# ============================================================
# Train:      299 batches
# Validation: 86 batches
# Test:       43 batches
# ============================================================
#
# ✅ Dataset cargado. Clases: ['CNV', 'DME', 'DRUSEN', 'NORMAL']

# %% [markdown]
# ## 2. Entrenamiento Multi-Seed (SIN Data Augmentation)
#
# Entrenamos el modelo con 5 semillas diferentes. Cada entrenamiento:
# 1. Fija la semilla
# 2. Crea y compila el modelo
# 3. Entrena 100 épocas **directamente sobre train_ds sin augmentation**
# 4. Evalúa en test y guarda resultados

# %%
# Definar semillas a probar
SEEDS = [42, 123, 456, 789, 999]
EPOCHS = 100
LEARNING_RATE = 1e-5
DROPOUT = 0.4

# Listas para almacenar resultados
histories = []
results_per_seed = []  # [test_loss, test_accuracy] para cada seed
models_seed = []

print(f"Iniciando entrenamiento con {len(SEEDS)} semillas...\n")
# Out:
# Iniciando entrenamiento con 5 semillas...

# %%
# Loop sobre semillas
for idx, seed in enumerate(SEEDS, 1):
    print(f"\n{'='*60}")
    print(f"SEED {idx}/{len(SEEDS)}: {seed}")
    print(f"{'='*60}")
    
    # 1. Establecer semilla
    set_seeds(seed)
    
    # 2. Crear modelo (SIN data augmentation)
    model = resnet_model.create_resnet_model(
        input_shape=(224, 224, 3),
        num_classes=4,
        dropout_rate=DROPOUT
    )
    
    # 3. Compilar modelo
    model = resnet_model.compile_resnet_model(
        model,
        learning_rate=LEARNING_RATE,
        metrics=['accuracy']
    )
    
    # 4. Crear callbacks personalizados
    from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
    import tempfile
    
    # Crear directorio temporal para guardar el mejor modelo
    tmp_dir = tempfile.mkdtemp()
    best_model_path = f"{tmp_dir}/best_model_seed{seed}.keras"
    
    callbacks = [
        EarlyStopping(
            monitor='val_accuracy',
            mode='max',
            patience=30,
            restore_best_weights=True,
            verbose=1
        ),
        ModelCheckpoint(
            best_model_path,
            monitor='val_accuracy',
            mode='max',
            save_best_only=True,
            verbose=0
        ),
        ReduceLROnPlateau(
            monitor='val_accuracy',
            mode='max',
            factor=0.2,
            patience=2,
            min_lr=1e-8,
            verbose=1
        )
    ]
    
    # 5. Entrenar (directamente en train_ds SIN augmentation)
    print(f"\nEntrenando por {EPOCHS} épocas...")
    history = model.fit(
        train_ds,  # <--- SIN data augmentation aplicada
        validation_data=val_ds,
        epochs=EPOCHS,
        callbacks=callbacks,
        verbose=1
    )
    
    # 6. Cargar el mejor modelo guardado
    model = tf.keras.models.load_model(best_model_path)
    
    # 7. Evaluar en test
    results = model.evaluate(test_ds, verbose=0)
    test_loss, test_acc = results[0], results[1]
    
    # 8. Guardar resultados
    histories.append(history)
    results_per_seed.append([test_loss, test_acc])
    models_seed.append(model)
    
    print(f"\n✅ Seed {seed} completada:")
    print(f"   - Test Loss:     {test_loss:.4f}")
    print(f"   - Test Accuracy: {test_acc:.4f}")
    print(f"   - Épocas ejecutadas: {len(history.history['loss'])}")
# Out:
# ============================================================
# SEED 1/5: 42
# ============================================================
#
# Entrenando por 100 épocas...
# Epoch 1/100
# I0000 00:00:1774946880.498036 1020473 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 127s 286ms/step - accuracy: 0.8061 - loss: 0.5450 - val_accuracy: 0.9045 - val_loss: 0.3029 - learning_rate: 1.0000e-05
# Epoch 2/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 158ms/step - accuracy: 0.9414 - loss: 0.1821 - val_accuracy: 0.9423 - val_loss: 0.1708 - learning_rate: 1.0000e-05
# Epoch 3/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 158ms/step - accuracy: 0.9608 - loss: 0.1223 - val_accuracy: 0.9571 - val_loss: 0.1330 - learning_rate: 1.0000e-05
# Epoch 4/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9726 - loss: 0.0857 - val_accuracy: 0.9591 - val_loss: 0.1266 - learning_rate: 1.0000e-05
# Epoch 5/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9830 - loss: 0.0572 - val_accuracy: 0.9590 - val_loss: 0.1377 - learning_rate: 1.0000e-05
# Epoch 6/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9891 - loss: 0.0390 - val_accuracy: 0.9624 - val_loss: 0.1297 - learning_rate: 1.0000e-05
# Epoch 7/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 156ms/step - accuracy: 0.9927 - loss: 0.0274 - val_accuracy: 0.9625 - val_loss: 0.1362 - learning_rate: 1.0000e-05
# Epoch 8/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9945 - loss: 0.0205 - val_accuracy: 0.9627 - val_loss: 0.1435 - learning_rate: 1.0000e-05
# Epoch 9/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 156ms/step - accuracy: 0.9956 - loss: 0.0165 - val_accuracy: 0.9632 - val_loss: 0.1500 - learning_rate: 1.0000e-05
# Epoch 10/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9957 - loss: 0.0146 - val_accuracy: 0.9627 - val_loss: 0.1542 - learning_rate: 1.0000e-05
# Epoch 11/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9967 - loss: 0.0111
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9965 - loss: 0.0110 - val_accuracy: 0.9612 - val_loss: 0.1713 - learning_rate: 1.0000e-05
# Epoch 12/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9975 - loss: 0.0086 - val_accuracy: 0.9642 - val_loss: 0.1561 - learning_rate: 2.0000e-06
# Epoch 13/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9975 - loss: 0.0077 - val_accuracy: 0.9644 - val_loss: 0.1579 - learning_rate: 2.0000e-06
# Epoch 14/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9973 - loss: 0.0076 - val_accuracy: 0.9644 - val_loss: 0.1596 - learning_rate: 2.0000e-06
# Epoch 15/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9974 - loss: 0.0070
# Epoch 15: ReduceLROnPlateau reducing learning rate to 3.999999989900971e-07.
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9975 - loss: 0.0070 - val_accuracy: 0.9645 - val_loss: 0.1623 - learning_rate: 2.0000e-06
# Epoch 16/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9978 - loss: 0.0063 - val_accuracy: 0.9649 - val_loss: 0.1619 - learning_rate: 4.0000e-07
# Epoch 17/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 156ms/step - accuracy: 0.9977 - loss: 0.0064 - val_accuracy: 0.9651 - val_loss: 0.1617 - learning_rate: 4.0000e-07
# Epoch 18/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9980 - loss: 0.0058 - val_accuracy: 0.9651 - val_loss: 0.1627 - learning_rate: 4.0000e-07
# Epoch 19/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9977 - loss: 0.0060
# Epoch 19: ReduceLROnPlateau reducing learning rate to 8.00000009348878e-08.
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 156ms/step - accuracy: 0.9978 - loss: 0.0060 - val_accuracy: 0.9651 - val_loss: 0.1626 - learning_rate: 4.0000e-07
# Epoch 20/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 151ms/step - accuracy: 0.9978 - loss: 0.0059 - val_accuracy: 0.9651 - val_loss: 0.1630 - learning_rate: 8.0000e-08
# Epoch 21/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9981 - loss: 0.0056
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.5999999902760466e-08.
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9980 - loss: 0.0056 - val_accuracy: 0.9651 - val_loss: 0.1632 - learning_rate: 8.0000e-08
# Epoch 22/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9980 - loss: 0.0057 - val_accuracy: 0.9652 - val_loss: 0.1634 - learning_rate: 1.6000e-08
# Epoch 23/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 151ms/step - accuracy: 0.9980 - loss: 0.0057 - val_accuracy: 0.9651 - val_loss: 0.1635 - learning_rate: 1.6000e-08
# Epoch 24/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9981 - loss: 0.0056
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1e-08.
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9981 - loss: 0.0057 - val_accuracy: 0.9651 - val_loss: 0.1636 - learning_rate: 1.6000e-08
# Epoch 25/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9981 - loss: 0.0056 - val_accuracy: 0.9651 - val_loss: 0.1635 - learning_rate: 1.0000e-08
# Epoch 26/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9980 - loss: 0.0058 - val_accuracy: 0.9651 - val_loss: 0.1637 - learning_rate: 1.0000e-08
# Epoch 27/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 151ms/step - accuracy: 0.9982 - loss: 0.0056 - val_accuracy: 0.9651 - val_loss: 0.1635 - learning_rate: 1.0000e-08
# Epoch 28/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 151ms/step - accuracy: 0.9981 - loss: 0.0057 - val_accuracy: 0.9651 - val_loss: 0.1637 - learning_rate: 1.0000e-08
# Epoch 29/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9980 - loss: 0.0056 - val_accuracy: 0.9652 - val_loss: 0.1636 - learning_rate: 1.0000e-08
# Epoch 30/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9981 - loss: 0.0057 - val_accuracy: 0.9652 - val_loss: 0.1636 - learning_rate: 1.0000e-08
# Epoch 31/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 151ms/step - accuracy: 0.9980 - loss: 0.0057 - val_accuracy: 0.9651 - val_loss: 0.1637 - learning_rate: 1.0000e-08
# Epoch 32/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 151ms/step - accuracy: 0.9980 - loss: 0.0056 - val_accuracy: 0.9652 - val_loss: 0.1637 - learning_rate: 1.0000e-08
# Epoch 33/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9979 - loss: 0.0056 - val_accuracy: 0.9651 - val_loss: 0.1638 - learning_rate: 1.0000e-08
# Epoch 34/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 151ms/step - accuracy: 0.9979 - loss: 0.0057 - val_accuracy: 0.9651 - val_loss: 0.1637 - learning_rate: 1.0000e-08
# Epoch 35/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 151ms/step - accuracy: 0.9980 - loss: 0.0058 - val_accuracy: 0.9651 - val_loss: 0.1638 - learning_rate: 1.0000e-08
# Epoch 36/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 151ms/step - accuracy: 0.9979 - loss: 0.0059 - val_accuracy: 0.9650 - val_loss: 0.1638 - learning_rate: 1.0000e-08
# Epoch 37/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9980 - loss: 0.0055 - val_accuracy: 0.9652 - val_loss: 0.1638 - learning_rate: 1.0000e-08
# Epoch 38/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9980 - loss: 0.0058 - val_accuracy: 0.9650 - val_loss: 0.1639 - learning_rate: 1.0000e-08
# Epoch 39/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 151ms/step - accuracy: 0.9979 - loss: 0.0060 - val_accuracy: 0.9650 - val_loss: 0.1638 - learning_rate: 1.0000e-08
# Epoch 40/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9979 - loss: 0.0056 - val_accuracy: 0.9651 - val_loss: 0.1639 - learning_rate: 1.0000e-08
# Epoch 41/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9981 - loss: 0.0059 - val_accuracy: 0.9650 - val_loss: 0.1640 - learning_rate: 1.0000e-08
# Epoch 42/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9981 - loss: 0.0055 - val_accuracy: 0.9651 - val_loss: 0.1640 - learning_rate: 1.0000e-08
# Epoch 43/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9980 - loss: 0.0055 - val_accuracy: 0.9651 - val_loss: 0.1639 - learning_rate: 1.0000e-08
# Epoch 44/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9980 - loss: 0.0055 - val_accuracy: 0.9650 - val_loss: 0.1640 - learning_rate: 1.0000e-08
# Epoch 45/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9979 - loss: 0.0056 - val_accuracy: 0.9650 - val_loss: 0.1640 - learning_rate: 1.0000e-08
# Epoch 46/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9981 - loss: 0.0054 - val_accuracy: 0.9650 - val_loss: 0.1640 - learning_rate: 1.0000e-08
# Epoch 47/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9981 - loss: 0.0055 - val_accuracy: 0.9650 - val_loss: 0.1640 - learning_rate: 1.0000e-08
# Epoch 48/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 151ms/step - accuracy: 0.9982 - loss: 0.0054 - val_accuracy: 0.9651 - val_loss: 0.1640 - learning_rate: 1.0000e-08
# Epoch 49/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9979 - loss: 0.0058 - val_accuracy: 0.9650 - val_loss: 0.1641 - learning_rate: 1.0000e-08
# Epoch 50/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 151ms/step - accuracy: 0.9981 - loss: 0.0056 - val_accuracy: 0.9650 - val_loss: 0.1641 - learning_rate: 1.0000e-08
# Epoch 51/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 151ms/step - accuracy: 0.9980 - loss: 0.0055 - val_accuracy: 0.9650 - val_loss: 0.1641 - learning_rate: 1.0000e-08
# Epoch 52/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 151ms/step - accuracy: 0.9979 - loss: 0.0057 - val_accuracy: 0.9651 - val_loss: 0.1641 - learning_rate: 1.0000e-08
# Epoch 53/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 151ms/step - accuracy: 0.9980 - loss: 0.0054 - val_accuracy: 0.9650 - val_loss: 0.1641 - learning_rate: 1.0000e-08
# Epoch 54/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 151ms/step - accuracy: 0.9979 - loss: 0.0057 - val_accuracy: 0.9650 - val_loss: 0.1642 - learning_rate: 1.0000e-08
# Epoch 55/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 151ms/step - accuracy: 0.9981 - loss: 0.0055 - val_accuracy: 0.9649 - val_loss: 0.1642 - learning_rate: 1.0000e-08
# Epoch 56/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 151ms/step - accuracy: 0.9979 - loss: 0.0057 - val_accuracy: 0.9649 - val_loss: 0.1642 - learning_rate: 1.0000e-08
# Epoch 57/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 151ms/step - accuracy: 0.9980 - loss: 0.0055 - val_accuracy: 0.9651 - val_loss: 0.1642 - learning_rate: 1.0000e-08
# Epoch 58/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 151ms/step - accuracy: 0.9979 - loss: 0.0058 - val_accuracy: 0.9650 - val_loss: 0.1642 - learning_rate: 1.0000e-08
# Epoch 59/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 151ms/step - accuracy: 0.9979 - loss: 0.0057 - val_accuracy: 0.9649 - val_loss: 0.1643 - learning_rate: 1.0000e-08
# Epoch 59: early stopping
# Restoring model weights from the end of the best epoch: 29.
#
# ✅ Seed 42 completada:
#    - Test Loss:     0.1820
#    - Test Accuracy: 0.9599
#    - Épocas ejecutadas: 59
#
# ============================================================
# SEED 2/5: 123
# ============================================================
#
# Entrenando por 100 épocas...
# Epoch 1/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 90s 208ms/step - accuracy: 0.8479 - loss: 0.4221 - val_accuracy: 0.9158 - val_loss: 0.2481 - learning_rate: 1.0000e-05
# Epoch 2/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9463 - loss: 0.1641 - val_accuracy: 0.9420 - val_loss: 0.1715 - learning_rate: 1.0000e-05
# Epoch 3/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9650 - loss: 0.1092 - val_accuracy: 0.9580 - val_loss: 0.1276 - learning_rate: 1.0000e-05
# Epoch 4/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9760 - loss: 0.0751 - val_accuracy: 0.9595 - val_loss: 0.1250 - learning_rate: 1.0000e-05
# Epoch 5/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9844 - loss: 0.0499 - val_accuracy: 0.9609 - val_loss: 0.1294 - learning_rate: 1.0000e-05
# Epoch 6/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 159ms/step - accuracy: 0.9908 - loss: 0.0321 - val_accuracy: 0.9621 - val_loss: 0.1308 - learning_rate: 1.0000e-05
# Epoch 7/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 156ms/step - accuracy: 0.9933 - loss: 0.0231 - val_accuracy: 0.9641 - val_loss: 0.1354 - learning_rate: 1.0000e-05
# Epoch 8/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9951 - loss: 0.0169 - val_accuracy: 0.9640 - val_loss: 0.1436 - learning_rate: 1.0000e-05
# Epoch 9/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9956 - loss: 0.0142 - val_accuracy: 0.9650 - val_loss: 0.1514 - learning_rate: 1.0000e-05
# Epoch 10/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9963 - loss: 0.0112 - val_accuracy: 0.9643 - val_loss: 0.1610 - learning_rate: 1.0000e-05
# Epoch 11/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9969 - loss: 0.0096
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 151ms/step - accuracy: 0.9965 - loss: 0.0100 - val_accuracy: 0.9643 - val_loss: 0.1645 - learning_rate: 1.0000e-05
# Epoch 12/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 156ms/step - accuracy: 0.9975 - loss: 0.0075 - val_accuracy: 0.9654 - val_loss: 0.1588 - learning_rate: 2.0000e-06
# Epoch 13/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 156ms/step - accuracy: 0.9975 - loss: 0.0066 - val_accuracy: 0.9658 - val_loss: 0.1612 - learning_rate: 2.0000e-06
# Epoch 14/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 151ms/step - accuracy: 0.9975 - loss: 0.0063 - val_accuracy: 0.9652 - val_loss: 0.1641 - learning_rate: 2.0000e-06
# Epoch 15/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9979 - loss: 0.0059
# Epoch 15: ReduceLROnPlateau reducing learning rate to 3.999999989900971e-07.
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 151ms/step - accuracy: 0.9978 - loss: 0.0059 - val_accuracy: 0.9654 - val_loss: 0.1648 - learning_rate: 2.0000e-06
# Epoch 16/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 156ms/step - accuracy: 0.9979 - loss: 0.0055 - val_accuracy: 0.9661 - val_loss: 0.1659 - learning_rate: 4.0000e-07
# Epoch 17/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 151ms/step - accuracy: 0.9979 - loss: 0.0053 - val_accuracy: 0.9660 - val_loss: 0.1660 - learning_rate: 4.0000e-07
# Epoch 18/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9980 - loss: 0.0052
# Epoch 18: ReduceLROnPlateau reducing learning rate to 8.00000009348878e-08.
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9980 - loss: 0.0052 - val_accuracy: 0.9660 - val_loss: 0.1672 - learning_rate: 4.0000e-07
# Epoch 19/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9981 - loss: 0.0052 - val_accuracy: 0.9658 - val_loss: 0.1671 - learning_rate: 8.0000e-08
# Epoch 20/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9978 - loss: 0.0052
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.5999999902760466e-08.
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 151ms/step - accuracy: 0.9981 - loss: 0.0051 - val_accuracy: 0.9658 - val_loss: 0.1670 - learning_rate: 8.0000e-08
# Epoch 21/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9981 - loss: 0.0051 - val_accuracy: 0.9658 - val_loss: 0.1669 - learning_rate: 1.6000e-08
# Epoch 22/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9981 - loss: 0.0052
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1e-08.
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 151ms/step - accuracy: 0.9981 - loss: 0.0052 - val_accuracy: 0.9660 - val_loss: 0.1670 - learning_rate: 1.6000e-08
# Epoch 23/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 151ms/step - accuracy: 0.9981 - loss: 0.0051 - val_accuracy: 0.9658 - val_loss: 0.1671 - learning_rate: 1.0000e-08
# Epoch 24/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9979 - loss: 0.0052 - val_accuracy: 0.9660 - val_loss: 0.1670 - learning_rate: 1.0000e-08
# Epoch 25/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9980 - loss: 0.0051 - val_accuracy: 0.9659 - val_loss: 0.1671 - learning_rate: 1.0000e-08
# Epoch 26/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9979 - loss: 0.0052 - val_accuracy: 0.9659 - val_loss: 0.1671 - learning_rate: 1.0000e-08
# Epoch 27/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9981 - loss: 0.0051 - val_accuracy: 0.9659 - val_loss: 0.1670 - learning_rate: 1.0000e-08
# Epoch 28/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9983 - loss: 0.0049 - val_accuracy: 0.9658 - val_loss: 0.1670 - learning_rate: 1.0000e-08
# Epoch 29/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9980 - loss: 0.0051 - val_accuracy: 0.9659 - val_loss: 0.1671 - learning_rate: 1.0000e-08
# Epoch 30/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9981 - loss: 0.0051 - val_accuracy: 0.9659 - val_loss: 0.1672 - learning_rate: 1.0000e-08
# Epoch 31/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9981 - loss: 0.0049 - val_accuracy: 0.9659 - val_loss: 0.1672 - learning_rate: 1.0000e-08
# Epoch 32/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9982 - loss: 0.0050 - val_accuracy: 0.9658 - val_loss: 0.1671 - learning_rate: 1.0000e-08
# Epoch 33/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9981 - loss: 0.0048 - val_accuracy: 0.9658 - val_loss: 0.1671 - learning_rate: 1.0000e-08
# Epoch 34/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9978 - loss: 0.0052 - val_accuracy: 0.9659 - val_loss: 0.1673 - learning_rate: 1.0000e-08
# Epoch 35/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9980 - loss: 0.0051 - val_accuracy: 0.9659 - val_loss: 0.1671 - learning_rate: 1.0000e-08
# Epoch 36/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9979 - loss: 0.0051 - val_accuracy: 0.9658 - val_loss: 0.1672 - learning_rate: 1.0000e-08
# Epoch 37/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9981 - loss: 0.0050 - val_accuracy: 0.9658 - val_loss: 0.1672 - learning_rate: 1.0000e-08
# Epoch 38/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9982 - loss: 0.0048 - val_accuracy: 0.9660 - val_loss: 0.1672 - learning_rate: 1.0000e-08
# Epoch 39/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9980 - loss: 0.0050 - val_accuracy: 0.9659 - val_loss: 0.1673 - learning_rate: 1.0000e-08
# Epoch 40/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9982 - loss: 0.0051 - val_accuracy: 0.9659 - val_loss: 0.1673 - learning_rate: 1.0000e-08
# Epoch 41/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9980 - loss: 0.0049 - val_accuracy: 0.9659 - val_loss: 0.1673 - learning_rate: 1.0000e-08
# Epoch 42/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9982 - loss: 0.0051 - val_accuracy: 0.9659 - val_loss: 0.1674 - learning_rate: 1.0000e-08
# Epoch 43/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9979 - loss: 0.0051 - val_accuracy: 0.9659 - val_loss: 0.1673 - learning_rate: 1.0000e-08
# Epoch 44/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9980 - loss: 0.0052 - val_accuracy: 0.9658 - val_loss: 0.1674 - learning_rate: 1.0000e-08
# Epoch 45/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 151ms/step - accuracy: 0.9981 - loss: 0.0049 - val_accuracy: 0.9659 - val_loss: 0.1674 - learning_rate: 1.0000e-08
# Epoch 46/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9980 - loss: 0.0051 - val_accuracy: 0.9659 - val_loss: 0.1675 - learning_rate: 1.0000e-08
# Epoch 46: early stopping
# Restoring model weights from the end of the best epoch: 16.
#
# ✅ Seed 123 completada:
#    - Test Loss:     0.1853
#    - Test Accuracy: 0.9621
#    - Épocas ejecutadas: 46
#
# ============================================================
# SEED 3/5: 456
# ============================================================
#
# Entrenando por 100 épocas...
# Epoch 1/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 91s 212ms/step - accuracy: 0.8221 - loss: 0.4867 - val_accuracy: 0.9053 - val_loss: 0.2909 - learning_rate: 1.0000e-05
# Epoch 2/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 158ms/step - accuracy: 0.9414 - loss: 0.1776 - val_accuracy: 0.9354 - val_loss: 0.1925 - learning_rate: 1.0000e-05
# Epoch 3/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 158ms/step - accuracy: 0.9618 - loss: 0.1184 - val_accuracy: 0.9579 - val_loss: 0.1299 - learning_rate: 1.0000e-05
# Epoch 4/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 158ms/step - accuracy: 0.9737 - loss: 0.0811 - val_accuracy: 0.9600 - val_loss: 0.1255 - learning_rate: 1.0000e-05
# Epoch 5/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9825 - loss: 0.0561 - val_accuracy: 0.9615 - val_loss: 0.1285 - learning_rate: 1.0000e-05
# Epoch 6/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9888 - loss: 0.0384 - val_accuracy: 0.9617 - val_loss: 0.1325 - learning_rate: 1.0000e-05
# Epoch 7/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9926 - loss: 0.0265 - val_accuracy: 0.9624 - val_loss: 0.1367 - learning_rate: 1.0000e-05
# Epoch 8/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9942 - loss: 0.0201 - val_accuracy: 0.9621 - val_loss: 0.1436 - learning_rate: 1.0000e-05
# Epoch 9/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9957 - loss: 0.0160
# Epoch 9: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9954 - loss: 0.0161 - val_accuracy: 0.9624 - val_loss: 0.1522 - learning_rate: 1.0000e-05
# Epoch 10/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9969 - loss: 0.0111 - val_accuracy: 0.9629 - val_loss: 0.1488 - learning_rate: 2.0000e-06
# Epoch 11/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9971 - loss: 0.0099 - val_accuracy: 0.9626 - val_loss: 0.1511 - learning_rate: 2.0000e-06
# Epoch 12/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9971 - loss: 0.0091 - val_accuracy: 0.9633 - val_loss: 0.1517 - learning_rate: 2.0000e-06
# Epoch 13/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9973 - loss: 0.0087 - val_accuracy: 0.9629 - val_loss: 0.1546 - learning_rate: 2.0000e-06
# Epoch 14/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9972 - loss: 0.0087
# Epoch 14: ReduceLROnPlateau reducing learning rate to 3.999999989900971e-07.
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9973 - loss: 0.0085 - val_accuracy: 0.9629 - val_loss: 0.1559 - learning_rate: 2.0000e-06
# Epoch 15/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9977 - loss: 0.0074 - val_accuracy: 0.9641 - val_loss: 0.1555 - learning_rate: 4.0000e-07
# Epoch 16/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9977 - loss: 0.0072 - val_accuracy: 0.9644 - val_loss: 0.1557 - learning_rate: 4.0000e-07
# Epoch 17/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9978 - loss: 0.0067 - val_accuracy: 0.9646 - val_loss: 0.1571 - learning_rate: 4.0000e-07
# Epoch 18/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 154ms/step - accuracy: 0.9976 - loss: 0.0071 - val_accuracy: 0.9644 - val_loss: 0.1580 - learning_rate: 4.0000e-07
# Epoch 19/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9977 - loss: 0.0073
# Epoch 19: ReduceLROnPlateau reducing learning rate to 8.00000009348878e-08.
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9977 - loss: 0.0069 - val_accuracy: 0.9643 - val_loss: 0.1591 - learning_rate: 4.0000e-07
# Epoch 20/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 154ms/step - accuracy: 0.9978 - loss: 0.0068 - val_accuracy: 0.9646 - val_loss: 0.1587 - learning_rate: 8.0000e-08
# Epoch 21/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9981 - loss: 0.0067
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.5999999902760466e-08.
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 155ms/step - accuracy: 0.9979 - loss: 0.0066 - val_accuracy: 0.9644 - val_loss: 0.1586 - learning_rate: 8.0000e-08
# Epoch 22/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 154ms/step - accuracy: 0.9980 - loss: 0.0064 - val_accuracy: 0.9645 - val_loss: 0.1586 - learning_rate: 1.6000e-08
# Epoch 23/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9976 - loss: 0.0070
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1e-08.
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9976 - loss: 0.0067 - val_accuracy: 0.9645 - val_loss: 0.1588 - learning_rate: 1.6000e-08
# Epoch 24/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9979 - loss: 0.0064 - val_accuracy: 0.9645 - val_loss: 0.1588 - learning_rate: 1.0000e-08
# Epoch 25/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9978 - loss: 0.0066 - val_accuracy: 0.9645 - val_loss: 0.1588 - learning_rate: 1.0000e-08
# Epoch 26/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9976 - loss: 0.0067 - val_accuracy: 0.9645 - val_loss: 0.1588 - learning_rate: 1.0000e-08
# Epoch 27/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 154ms/step - accuracy: 0.9980 - loss: 0.0062 - val_accuracy: 0.9645 - val_loss: 0.1588 - learning_rate: 1.0000e-08
# Epoch 28/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9980 - loss: 0.0065 - val_accuracy: 0.9645 - val_loss: 0.1588 - learning_rate: 1.0000e-08
# Epoch 29/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9977 - loss: 0.0067 - val_accuracy: 0.9645 - val_loss: 0.1589 - learning_rate: 1.0000e-08
# Epoch 30/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9979 - loss: 0.0065 - val_accuracy: 0.9645 - val_loss: 0.1588 - learning_rate: 1.0000e-08
# Epoch 31/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9982 - loss: 0.0062 - val_accuracy: 0.9645 - val_loss: 0.1588 - learning_rate: 1.0000e-08
# Epoch 32/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 154ms/step - accuracy: 0.9980 - loss: 0.0064 - val_accuracy: 0.9645 - val_loss: 0.1589 - learning_rate: 1.0000e-08
# Epoch 33/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9978 - loss: 0.0065 - val_accuracy: 0.9645 - val_loss: 0.1590 - learning_rate: 1.0000e-08
# Epoch 34/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 154ms/step - accuracy: 0.9979 - loss: 0.0064 - val_accuracy: 0.9645 - val_loss: 0.1590 - learning_rate: 1.0000e-08
# Epoch 35/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9979 - loss: 0.0065 - val_accuracy: 0.9644 - val_loss: 0.1591 - learning_rate: 1.0000e-08
# Epoch 36/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 154ms/step - accuracy: 0.9979 - loss: 0.0064 - val_accuracy: 0.9645 - val_loss: 0.1590 - learning_rate: 1.0000e-08
# Epoch 37/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9977 - loss: 0.0067 - val_accuracy: 0.9645 - val_loss: 0.1591 - learning_rate: 1.0000e-08
# Epoch 38/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9980 - loss: 0.0063 - val_accuracy: 0.9644 - val_loss: 0.1591 - learning_rate: 1.0000e-08
# Epoch 39/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9978 - loss: 0.0065 - val_accuracy: 0.9645 - val_loss: 0.1591 - learning_rate: 1.0000e-08
# Epoch 40/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9979 - loss: 0.0065 - val_accuracy: 0.9644 - val_loss: 0.1591 - learning_rate: 1.0000e-08
# Epoch 41/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9978 - loss: 0.0065 - val_accuracy: 0.9645 - val_loss: 0.1592 - learning_rate: 1.0000e-08
# Epoch 42/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9979 - loss: 0.0064 - val_accuracy: 0.9645 - val_loss: 0.1592 - learning_rate: 1.0000e-08
# Epoch 43/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9980 - loss: 0.0064 - val_accuracy: 0.9645 - val_loss: 0.1593 - learning_rate: 1.0000e-08
# Epoch 44/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9978 - loss: 0.0064 - val_accuracy: 0.9644 - val_loss: 0.1592 - learning_rate: 1.0000e-08
# Epoch 45/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9979 - loss: 0.0064 - val_accuracy: 0.9645 - val_loss: 0.1593 - learning_rate: 1.0000e-08
# Epoch 46/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9978 - loss: 0.0064 - val_accuracy: 0.9645 - val_loss: 0.1593 - learning_rate: 1.0000e-08
# Epoch 47/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9982 - loss: 0.0061 - val_accuracy: 0.9644 - val_loss: 0.1593 - learning_rate: 1.0000e-08
# Epoch 47: early stopping
# Restoring model weights from the end of the best epoch: 17.
#
# ✅ Seed 456 completada:
#    - Test Loss:     0.1724
#    - Test Accuracy: 0.9607
#    - Épocas ejecutadas: 47
#
# ============================================================
# SEED 4/5: 789
# ============================================================
#
# Entrenando por 100 épocas...
# Epoch 1/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 90s 208ms/step - accuracy: 0.8032 - loss: 0.5230 - val_accuracy: 0.9104 - val_loss: 0.2637 - learning_rate: 1.0000e-05
# Epoch 2/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 158ms/step - accuracy: 0.9411 - loss: 0.1820 - val_accuracy: 0.9454 - val_loss: 0.1655 - learning_rate: 1.0000e-05
# Epoch 3/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9607 - loss: 0.1217 - val_accuracy: 0.9553 - val_loss: 0.1354 - learning_rate: 1.0000e-05
# Epoch 4/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9723 - loss: 0.0851 - val_accuracy: 0.9586 - val_loss: 0.1287 - learning_rate: 1.0000e-05
# Epoch 5/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9820 - loss: 0.0572 - val_accuracy: 0.9578 - val_loss: 0.1392 - learning_rate: 1.0000e-05
# Epoch 6/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9878 - loss: 0.0398 - val_accuracy: 0.9618 - val_loss: 0.1347 - learning_rate: 1.0000e-05
# Epoch 7/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9924 - loss: 0.0271 - val_accuracy: 0.9615 - val_loss: 0.1442 - learning_rate: 1.0000e-05
# Epoch 8/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9942 - loss: 0.0205 - val_accuracy: 0.9626 - val_loss: 0.1479 - learning_rate: 1.0000e-05
# Epoch 9/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 156ms/step - accuracy: 0.9953 - loss: 0.0160 - val_accuracy: 0.9628 - val_loss: 0.1523 - learning_rate: 1.0000e-05
# Epoch 10/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9961 - loss: 0.0131 - val_accuracy: 0.9622 - val_loss: 0.1640 - learning_rate: 1.0000e-05
# Epoch 11/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9971 - loss: 0.0107
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9966 - loss: 0.0113 - val_accuracy: 0.9621 - val_loss: 0.1685 - learning_rate: 1.0000e-05
# Epoch 12/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9975 - loss: 0.0080 - val_accuracy: 0.9646 - val_loss: 0.1642 - learning_rate: 2.0000e-06
# Epoch 13/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9975 - loss: 0.0075 - val_accuracy: 0.9640 - val_loss: 0.1667 - learning_rate: 2.0000e-06
# Epoch 14/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9977 - loss: 0.0068
# Epoch 14: ReduceLROnPlateau reducing learning rate to 3.999999989900971e-07.
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9976 - loss: 0.0070 - val_accuracy: 0.9644 - val_loss: 0.1687 - learning_rate: 2.0000e-06
# Epoch 15/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 158ms/step - accuracy: 0.9978 - loss: 0.0063 - val_accuracy: 0.9649 - val_loss: 0.1682 - learning_rate: 4.0000e-07
# Epoch 16/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9979 - loss: 0.0063 - val_accuracy: 0.9647 - val_loss: 0.1683 - learning_rate: 4.0000e-07
# Epoch 17/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9979 - loss: 0.0064
# Epoch 17: ReduceLROnPlateau reducing learning rate to 8.00000009348878e-08.
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9979 - loss: 0.0062 - val_accuracy: 0.9649 - val_loss: 0.1688 - learning_rate: 4.0000e-07
# Epoch 18/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9979 - loss: 0.0061 - val_accuracy: 0.9647 - val_loss: 0.1688 - learning_rate: 8.0000e-08
# Epoch 19/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9978 - loss: 0.0062
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.5999999902760466e-08.
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9980 - loss: 0.0060 - val_accuracy: 0.9646 - val_loss: 0.1690 - learning_rate: 8.0000e-08
# Epoch 20/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9980 - loss: 0.0058 - val_accuracy: 0.9647 - val_loss: 0.1692 - learning_rate: 1.6000e-08
# Epoch 21/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9981 - loss: 0.0059
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1e-08.
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 154ms/step - accuracy: 0.9981 - loss: 0.0058 - val_accuracy: 0.9647 - val_loss: 0.1691 - learning_rate: 1.6000e-08
# Epoch 22/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9980 - loss: 0.0060 - val_accuracy: 0.9647 - val_loss: 0.1692 - learning_rate: 1.0000e-08
# Epoch 23/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9981 - loss: 0.0060 - val_accuracy: 0.9648 - val_loss: 0.1690 - learning_rate: 1.0000e-08
# Epoch 24/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9981 - loss: 0.0057 - val_accuracy: 0.9647 - val_loss: 0.1692 - learning_rate: 1.0000e-08
# Epoch 25/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9980 - loss: 0.0060 - val_accuracy: 0.9648 - val_loss: 0.1691 - learning_rate: 1.0000e-08
# Epoch 26/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9982 - loss: 0.0058 - val_accuracy: 0.9649 - val_loss: 0.1692 - learning_rate: 1.0000e-08
# Epoch 27/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9981 - loss: 0.0058 - val_accuracy: 0.9648 - val_loss: 0.1693 - learning_rate: 1.0000e-08
# Epoch 28/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9979 - loss: 0.0059 - val_accuracy: 0.9648 - val_loss: 0.1693 - learning_rate: 1.0000e-08
# Epoch 29/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9981 - loss: 0.0059 - val_accuracy: 0.9646 - val_loss: 0.1694 - learning_rate: 1.0000e-08
# Epoch 30/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9980 - loss: 0.0059 - val_accuracy: 0.9647 - val_loss: 0.1693 - learning_rate: 1.0000e-08
# Epoch 31/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9979 - loss: 0.0059 - val_accuracy: 0.9647 - val_loss: 0.1693 - learning_rate: 1.0000e-08
# Epoch 32/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9981 - loss: 0.0059 - val_accuracy: 0.9647 - val_loss: 0.1693 - learning_rate: 1.0000e-08
# Epoch 33/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9981 - loss: 0.0059 - val_accuracy: 0.9647 - val_loss: 0.1694 - learning_rate: 1.0000e-08
# Epoch 34/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9981 - loss: 0.0058 - val_accuracy: 0.9648 - val_loss: 0.1695 - learning_rate: 1.0000e-08
# Epoch 35/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9979 - loss: 0.0060 - val_accuracy: 0.9647 - val_loss: 0.1695 - learning_rate: 1.0000e-08
# Epoch 36/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9980 - loss: 0.0057 - val_accuracy: 0.9648 - val_loss: 0.1694 - learning_rate: 1.0000e-08
# Epoch 37/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9979 - loss: 0.0060 - val_accuracy: 0.9647 - val_loss: 0.1696 - learning_rate: 1.0000e-08
# Epoch 38/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9981 - loss: 0.0057 - val_accuracy: 0.9648 - val_loss: 0.1696 - learning_rate: 1.0000e-08
# Epoch 39/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9980 - loss: 0.0057 - val_accuracy: 0.9648 - val_loss: 0.1695 - learning_rate: 1.0000e-08
# Epoch 40/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9981 - loss: 0.0057 - val_accuracy: 0.9647 - val_loss: 0.1696 - learning_rate: 1.0000e-08
# Epoch 41/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9978 - loss: 0.0058 - val_accuracy: 0.9648 - val_loss: 0.1697 - learning_rate: 1.0000e-08
# Epoch 42/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9978 - loss: 0.0060 - val_accuracy: 0.9648 - val_loss: 0.1696 - learning_rate: 1.0000e-08
# Epoch 43/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9980 - loss: 0.0058 - val_accuracy: 0.9649 - val_loss: 0.1697 - learning_rate: 1.0000e-08
# Epoch 44/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9980 - loss: 0.0058 - val_accuracy: 0.9648 - val_loss: 0.1697 - learning_rate: 1.0000e-08
# Epoch 45/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9981 - loss: 0.0059 - val_accuracy: 0.9648 - val_loss: 0.1696 - learning_rate: 1.0000e-08
# Epoch 45: early stopping
# Restoring model weights from the end of the best epoch: 15.
#
# ✅ Seed 789 completada:
#    - Test Loss:     0.1804
#    - Test Accuracy: 0.9607
#    - Épocas ejecutadas: 45
#
# ============================================================
# SEED 5/5: 999
# ============================================================
#
# Entrenando por 100 épocas...
# Epoch 1/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 89s 209ms/step - accuracy: 0.8284 - loss: 0.4675 - val_accuracy: 0.9170 - val_loss: 0.2544 - learning_rate: 1.0000e-05
# Epoch 2/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 158ms/step - accuracy: 0.9423 - loss: 0.1745 - val_accuracy: 0.9419 - val_loss: 0.1720 - learning_rate: 1.0000e-05
# Epoch 3/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9613 - loss: 0.1180 - val_accuracy: 0.9560 - val_loss: 0.1297 - learning_rate: 1.0000e-05
# Epoch 4/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 158ms/step - accuracy: 0.9742 - loss: 0.0796 - val_accuracy: 0.9591 - val_loss: 0.1247 - learning_rate: 1.0000e-05
# Epoch 5/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 158ms/step - accuracy: 0.9832 - loss: 0.0537 - val_accuracy: 0.9613 - val_loss: 0.1258 - learning_rate: 1.0000e-05
# Epoch 6/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9898 - loss: 0.0351 - val_accuracy: 0.9615 - val_loss: 0.1323 - learning_rate: 1.0000e-05
# Epoch 7/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9930 - loss: 0.0239 - val_accuracy: 0.9622 - val_loss: 0.1397 - learning_rate: 1.0000e-05
# Epoch 8/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9947 - loss: 0.0191 - val_accuracy: 0.9625 - val_loss: 0.1469 - learning_rate: 1.0000e-05
# Epoch 9/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9959 - loss: 0.0140 - val_accuracy: 0.9606 - val_loss: 0.1577 - learning_rate: 1.0000e-05
# Epoch 10/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9968 - loss: 0.0116
# Epoch 10: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9964 - loss: 0.0120 - val_accuracy: 0.9591 - val_loss: 0.1616 - learning_rate: 1.0000e-05
# Epoch 11/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 158ms/step - accuracy: 0.9973 - loss: 0.0090 - val_accuracy: 0.9628 - val_loss: 0.1576 - learning_rate: 2.0000e-06
# Epoch 12/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9973 - loss: 0.0081 - val_accuracy: 0.9635 - val_loss: 0.1588 - learning_rate: 2.0000e-06
# Epoch 13/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9977 - loss: 0.0073 - val_accuracy: 0.9636 - val_loss: 0.1612 - learning_rate: 2.0000e-06
# Epoch 14/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9976 - loss: 0.0071 - val_accuracy: 0.9636 - val_loss: 0.1619 - learning_rate: 2.0000e-06
# Epoch 15/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9978 - loss: 0.0069
# Epoch 15: ReduceLROnPlateau reducing learning rate to 3.999999989900971e-07.
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9976 - loss: 0.0068 - val_accuracy: 0.9633 - val_loss: 0.1635 - learning_rate: 2.0000e-06
# Epoch 16/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9979 - loss: 0.0063 - val_accuracy: 0.9639 - val_loss: 0.1647 - learning_rate: 4.0000e-07
# Epoch 17/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9981 - loss: 0.0059 - val_accuracy: 0.9640 - val_loss: 0.1647 - learning_rate: 4.0000e-07
# Epoch 18/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9981 - loss: 0.0056 - val_accuracy: 0.9640 - val_loss: 0.1656 - learning_rate: 4.0000e-07
# Epoch 19/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9980 - loss: 0.0057
# Epoch 19: ReduceLROnPlateau reducing learning rate to 8.00000009348878e-08.
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9981 - loss: 0.0056 - val_accuracy: 0.9640 - val_loss: 0.1657 - learning_rate: 4.0000e-07
# Epoch 20/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9980 - loss: 0.0055 - val_accuracy: 0.9639 - val_loss: 0.1657 - learning_rate: 8.0000e-08
# Epoch 21/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 47s 157ms/step - accuracy: 0.9979 - loss: 0.0055 - val_accuracy: 0.9642 - val_loss: 0.1660 - learning_rate: 8.0000e-08
# Epoch 22/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9983 - loss: 0.0050 - val_accuracy: 0.9640 - val_loss: 0.1662 - learning_rate: 8.0000e-08
# Epoch 23/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9982 - loss: 0.0053
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.5999999902760466e-08.
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9981 - loss: 0.0053 - val_accuracy: 0.9639 - val_loss: 0.1664 - learning_rate: 8.0000e-08
# Epoch 24/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9980 - loss: 0.0054 - val_accuracy: 0.9640 - val_loss: 0.1664 - learning_rate: 1.6000e-08
# Epoch 25/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9979 - loss: 0.0055
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1e-08.
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9979 - loss: 0.0054 - val_accuracy: 0.9640 - val_loss: 0.1664 - learning_rate: 1.6000e-08
# Epoch 26/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9982 - loss: 0.0051 - val_accuracy: 0.9639 - val_loss: 0.1665 - learning_rate: 1.0000e-08
# Epoch 27/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9979 - loss: 0.0054 - val_accuracy: 0.9639 - val_loss: 0.1665 - learning_rate: 1.0000e-08
# Epoch 28/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9980 - loss: 0.0055 - val_accuracy: 0.9640 - val_loss: 0.1665 - learning_rate: 1.0000e-08
# Epoch 29/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9981 - loss: 0.0053 - val_accuracy: 0.9640 - val_loss: 0.1665 - learning_rate: 1.0000e-08
# Epoch 30/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9981 - loss: 0.0052 - val_accuracy: 0.9639 - val_loss: 0.1666 - learning_rate: 1.0000e-08
# Epoch 31/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9978 - loss: 0.0056 - val_accuracy: 0.9640 - val_loss: 0.1666 - learning_rate: 1.0000e-08
# Epoch 32/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9980 - loss: 0.0053 - val_accuracy: 0.9640 - val_loss: 0.1666 - learning_rate: 1.0000e-08
# Epoch 33/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9983 - loss: 0.0053 - val_accuracy: 0.9639 - val_loss: 0.1666 - learning_rate: 1.0000e-08
# Epoch 34/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9980 - loss: 0.0054 - val_accuracy: 0.9640 - val_loss: 0.1666 - learning_rate: 1.0000e-08
# Epoch 35/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9982 - loss: 0.0053 - val_accuracy: 0.9640 - val_loss: 0.1667 - learning_rate: 1.0000e-08
# Epoch 36/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.9980 - loss: 0.0055 - val_accuracy: 0.9639 - val_loss: 0.1667 - learning_rate: 1.0000e-08
# Epoch 37/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9982 - loss: 0.0052 - val_accuracy: 0.9640 - val_loss: 0.1667 - learning_rate: 1.0000e-08
# Epoch 38/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9982 - loss: 0.0053 - val_accuracy: 0.9639 - val_loss: 0.1669 - learning_rate: 1.0000e-08
# Epoch 39/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9981 - loss: 0.0054 - val_accuracy: 0.9639 - val_loss: 0.1667 - learning_rate: 1.0000e-08
# Epoch 40/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9980 - loss: 0.0054 - val_accuracy: 0.9639 - val_loss: 0.1669 - learning_rate: 1.0000e-08
# Epoch 41/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9981 - loss: 0.0054 - val_accuracy: 0.9639 - val_loss: 0.1669 - learning_rate: 1.0000e-08
# Epoch 42/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9981 - loss: 0.0053 - val_accuracy: 0.9639 - val_loss: 0.1669 - learning_rate: 1.0000e-08
# Epoch 43/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9981 - loss: 0.0053 - val_accuracy: 0.9639 - val_loss: 0.1669 - learning_rate: 1.0000e-08
# Epoch 44/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9980 - loss: 0.0054 - val_accuracy: 0.9639 - val_loss: 0.1669 - learning_rate: 1.0000e-08
# Epoch 45/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9980 - loss: 0.0054 - val_accuracy: 0.9640 - val_loss: 0.1670 - learning_rate: 1.0000e-08
# Epoch 46/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9981 - loss: 0.0053 - val_accuracy: 0.9639 - val_loss: 0.1669 - learning_rate: 1.0000e-08
# Epoch 47/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9981 - loss: 0.0053 - val_accuracy: 0.9639 - val_loss: 0.1670 - learning_rate: 1.0000e-08
# Epoch 48/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9980 - loss: 0.0053 - val_accuracy: 0.9639 - val_loss: 0.1670 - learning_rate: 1.0000e-08
# Epoch 49/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 152ms/step - accuracy: 0.9981 - loss: 0.0054 - val_accuracy: 0.9639 - val_loss: 0.1670 - learning_rate: 1.0000e-08
# Epoch 50/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9980 - loss: 0.0054 - val_accuracy: 0.9639 - val_loss: 0.1670 - learning_rate: 1.0000e-08
# Epoch 51/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 46s 153ms/step - accuracy: 0.9983 - loss: 0.0051 - val_accuracy: 0.9639 - val_loss: 0.1670 - learning_rate: 1.0000e-08
# Epoch 51: early stopping
# Restoring model weights from the end of the best epoch: 21.
#
# ✅ Seed 999 completada:
#    - Test Loss:     0.1775
#    - Test Accuracy: 0.9593
#    - Épocas ejecutadas: 51

# %% [markdown]
# ## 3. Visualización de Curvas por Seed
#
# Mostramos las curvas de entrenamiento y validación para cada semilla de forma separada. **Se visualiza tanto la accuracy como el loss en validación.**

# %%
# Gráficos separados para cada seed (5 filas x 2 columnas)
fig, axes = plt.subplots(5, 2, figsize=(15, 20))

for idx, (seed, history) in enumerate(zip(SEEDS, histories)):
    # Columna 0: Accuracy (Train + Validation)
    ax_acc = axes[idx, 0]
    ax_acc.plot(history.history['accuracy'], label='Train Accuracy', linewidth=2, marker='o', markersize=4, alpha=0.7)
    ax_acc.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2, marker='s', markersize=4, alpha=0.7)
    ax_acc.set_title(f'Seed {seed} - Accuracy ({len(history.history["loss"])} épocas)', fontsize=11, fontweight='bold')
    ax_acc.set_xlabel('Epoch')
    ax_acc.set_ylabel('Accuracy')
    ax_acc.legend(loc='lower right')
    ax_acc.grid(True, alpha=0.3)
    ax_acc.set_ylim([0, 1])
    
    # Columna 1: Loss (Train + Validation)
    ax_loss = axes[idx, 1]
    ax_loss.plot(history.history['loss'], label='Train Loss', linewidth=2, marker='o', markersize=4, alpha=0.7)
    ax_loss.plot(history.history['val_loss'], label='Validation Loss', linewidth=2, marker='s', markersize=4, alpha=0.7)
    ax_loss.set_title(f'Seed {seed} - Loss ({len(history.history["loss"])} épocas)', fontsize=11, fontweight='bold')
    ax_loss.set_xlabel('Epoch')
    ax_loss.set_ylabel('Loss')
    ax_loss.legend(loc='upper right')
    ax_loss.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print("✅ Gráficos de curvas por seed completados")
# Out:
# ✅ Gráficos de curvas por seed completados

# %% [markdown]
# ## 4. Visualización Superpuesta (Todas las Seeds)
#
# Gráfico consolidado con todas las semillas superpuestas mostrando **validación accuracy y validación loss** para comparación visual directa.

# %%
# Colores para cada seed
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd']

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# Accuracy superpuesto (Validación)
for seed, history, color in zip(SEEDS, histories, colors):
    ax1.plot(history.history['val_accuracy'], label=f'Seed {seed}', linewidth=2.5, color=color, alpha=0.8, marker='o', markersize=3)

ax1.set_title('Validación Accuracy - Todas las Seeds (Sin Data Augmentation)', fontsize=13, fontweight='bold')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Validation Accuracy')
ax1.legend(loc='lower right')
ax1.grid(True, alpha=0.3)
ax1.set_ylim([0, 1])

# Loss superpuesto (Validación)
for seed, history, color in zip(SEEDS, histories, colors):
    ax2.plot(history.history['val_loss'], label=f'Seed {seed}', linewidth=2.5, color=color, alpha=0.8, marker='s', markersize=3)

ax2.set_title('Validación Loss - Todas las Seeds (Sin Data Augmentation)', fontsize=13, fontweight='bold')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Validation Loss')
ax2.legend(loc='upper right')
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print("✅ Gráficos superpuestos completados")
# Out:
# ✅ Gráficos superpuestos completados

# %% [markdown]
# ## 5. Resumen Estadístico Final
#
# Cálculo de media y desviación estándar para los resultados de las 5 semillas en el conjunto de test.

# %%
# Convertir resultados a array numpy
results_array = np.array(results_per_seed)

# Calcular estadísticas
test_loss_values = results_array[:, 0]
test_acc_values = results_array[:, 1]

mean_loss = test_loss_values.mean()
std_loss = test_loss_values.std()
mean_acc = test_acc_values.mean()
std_acc = test_acc_values.std()

print("\n" + "="*70)
print("RESUMEN FINAL - MÉTRICAS EN TEST (5 SEMILLAS - SIN DATA AUGMENTATION)")
print("="*70)
print(f"\nResultados individuales por seed:")
for seed, (loss, acc) in zip(SEEDS, results_per_seed):
    print(f"  Seed {seed:3d}: Loss = {loss:.4f}  |  Accuracy = {acc:.4f}")

print(f"\n{'-'*70}")
print(f"MEDIA Y DESVIACIÓN ESTÁNDAR:")
print(f"{'-'*70}")
print(f"Test Loss:     {mean_loss:.4f} ± {std_loss:.4f}")
print(f"Test Accuracy: {mean_acc:.4f} ± {std_acc:.4f}")
print(f"\nCoeficiente de Variación:")
print(f"  Loss CV:     {(std_loss / mean_loss * 100):.2f}%")
print(f"  Accuracy CV: {(std_acc / mean_acc * 100):.2f}%")
print("="*70)
# Out:
# ======================================================================
# RESUMEN FINAL - MÉTRICAS EN TEST (5 SEMILLAS - SIN DATA AUGMENTATION)
# ======================================================================
#
# Resultados individuales por seed:
#   Seed  42: Loss = 0.1820  |  Accuracy = 0.9599
#   Seed 123: Loss = 0.1853  |  Accuracy = 0.9621
#   Seed 456: Loss = 0.1724  |  Accuracy = 0.9607
#   Seed 789: Loss = 0.1804  |  Accuracy = 0.9607
#   Seed 999: Loss = 0.1775  |  Accuracy = 0.9593
#
# ----------------------------------------------------------------------
# MEDIA Y DESVIACIÓN ESTÁNDAR:
# ----------------------------------------------------------------------
# Test Loss:     0.1795 ± 0.0044
# Test Accuracy: 0.9605 ± 0.0009
#
# Coeficiente de Variación:
#   Loss CV:     2.44%
#   Accuracy CV: 0.10%
# ======================================================================

# %% [markdown]
# ## 6. Análisis Detallado del Mejor Modelo
#
# Evaluación adicional del modelo con mejor accuracy en test, incluyendo reporte de clasificación y matriz de confusión.

# %%
# Encontrar el mejor modelo (por accuracy en test)
best_idx = np.argmax(test_acc_values)
best_seed = SEEDS[best_idx]
best_model = models_seed[best_idx]
best_acc = test_acc_values[best_idx]
best_loss = test_loss_values[best_idx]

print(f"\nMejor modelo encontrado:")
print(f"  Seed: {best_seed}")
print(f"  Test Loss: {best_loss:.4f}")
print(f"  Test Accuracy: {best_acc:.4f}")
print(f"\nGenerando métricas adicionales...\n")

# Obtener predicciones del mejor modelo
y_true = []
y_probs = []

for images, labels in test_ds:
    y_true.extend(labels.numpy())
    preds = best_model.predict(images, verbose=0)
    y_probs.extend(preds)

y_true = np.array(y_true)
y_probs = np.array(y_probs)
y_pred = np.argmax(y_probs, axis=1)

# Reporte de clasificación
print(f"Reporte de Clasificación (Mejor Modelo - Seed {best_seed}):")
print(classification_report(y_true, y_pred, target_names=class_names))

# Matriz de confusión
import seaborn as sns
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.title(f'Matriz de Confusión - Mejor Modelo (Seed {best_seed}, Sin Data Augmentation)')
plt.xlabel('Predicción')
plt.ylabel('Real')
plt.show()
# Out:
# Mejor modelo encontrado:
#   Seed: 123
#   Test Loss: 0.1853
#   Test Accuracy: 0.9621
#
# Generando métricas adicionales...
#
# Reporte de Clasificación (Mejor Modelo - Seed 123):
#               precision    recall  f1-score   support
#
#          CNV       0.97      0.97      0.97      3746
#          DME       0.95      0.92      0.94      1161
#       DRUSEN       0.88      0.80      0.84       887
#       NORMAL       0.97      0.99      0.98      5139
#
#     accuracy                           0.96     10933
#    macro avg       0.94      0.92      0.93     10933
# weighted avg       0.96      0.96      0.96     10933
